# %%
from sklearn import *
import pandas as pd
import numpy as np
import xgboost as xgb

from sklearn.preprocessing import LabelEncoder
# Out:
# /usr/lib64/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/lib64/python3.6/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# /usr/lib64/python3.6/site-packages/sklearn/lda.py:6: DeprecationWarning: lda.LDA has been moved to discriminant_analysis.LinearDiscriminantAnalysis in 0.17 and will be removed in 0.19
#   "in 0.17 and will be removed in 0.19", DeprecationWarning)
# /usr/lib64/python3.6/site-packages/sklearn/learning_curve.py:23: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)
# /usr/lib64/python3.6/site-packages/sklearn/qda.py:6: DeprecationWarning: qda.QDA has been moved to discriminant_analysis.QuadraticDiscriminantAnalysis in 0.17 and will be removed in 0.19.
#   "in 0.17 and will be removed in 0.19.", DeprecationWarning)

# %%
train = pd.read_csv('./data/training_variants')
test = pd.read_csv('./data/test_variants')
trainx = pd.read_csv('./data/training_text', sep="\|\|", engine='python', header=None, skiprows=1, names=["ID","Text"])
testx = pd.read_csv('./data/test_text', sep="\|\|", engine='python', header=None, skiprows=1, names=["ID","Text"])
# Out:
# <input>:3: DeprecationWarning: invalid escape sequence \|
# <input>:3: DeprecationWarning: invalid escape sequence \|
# <input>:3: DeprecationWarning: invalid escape sequence \|
# <input>:3: DeprecationWarning: invalid escape sequence \|
# <input>:4: DeprecationWarning: invalid escape sequence \|
# <input>:3: DeprecationWarning: invalid escape sequence \|
# <input>:4: DeprecationWarning: invalid escape sequence \|
# <input>:3: DeprecationWarning: invalid escape sequence \|
# <input>:4: DeprecationWarning: invalid escape sequence \|
# <ipython-input-2-754d10cef5ec>:3: DeprecationWarning: invalid escape sequence \|
#   trainx = pd.read_csv('./data/training_text', sep="\|\|", engine='python', header=None, skiprows=1, names=["ID","Text"])
# <ipython-input-2-754d10cef5ec>:4: DeprecationWarning: invalid escape sequence \|
#   testx = pd.read_csv('./data/test_text', sep="\|\|", engine='python', header=None, skiprows=1, names=["ID","Text"])

# %%
train = pd.merge(train, trainx, how='left', on='ID').fillna('')
y = train['Class'].values
train = train.drop(['Class'], axis=1)

test = pd.merge(test, testx, how='left', on='ID').fillna('')
pid = test['ID'].values

# %%
train.shape
# Out:
# (3321, 50)

# %%
test.shape
# Out:
# (5668, 50)

# %%
train.head()
# Out:
#    ID    Gene             Variation  \
# 0   0  FAM58A  Truncating Mutations
# 1   1     CBL                 W802*
# 2   2     CBL                 Q249E
# 3   3     CBL                 N454D
# 4   4     CBL                 L399V
#
#                                                 Text
# 0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   Abstract Background  Non-small cell lung canc...
# 2   Abstract Background  Non-small cell lung canc...
# 3  Recent evidence has demonstrated that acquired...
# 4  Oncogenic mutations in the monomeric Casitas B...

# %%
test.head()
# Out:
#    ID     Gene Variation                                               Text
# 0   0    ACSL4     R570S  2. This mutation resulted in a myeloproliferat...
# 1   1    NAGLU     P521L   Abstract The Large Tumor Suppressor 1 (LATS1)...
# 2   2      PAH     L333F  Vascular endothelial growth factor receptor (V...
# 3   3     ING1     A148D  Inflammatory myofibroblastic tumor (IMT) is a ...
# 4   4  TMEM216      G77A   Abstract Retinoblastoma is a pediatric retina...

# %%
df_all = pd.concat((train, test), axis=0, ignore_index=True)
df_all['Gene_Share'] = df_all.apply(lambda r: sum([1 for w in r['Gene'].split(' ') if w in r['Text'].split(' ')]), axis=1)
df_all['Variation_Share'] = df_all.apply(lambda r: sum([1 for w in r['Variation'].split(' ') if w in r['Text'].split(' ')]), axis=1)

# %%
df_all.head()
# Out:
#    ID    Gene             Variation  \
# 0   0  FAM58A  Truncating Mutations
# 1   1     CBL                 W802*
# 2   2     CBL                 Q249E
# 3   3     CBL                 N454D
# 4   4     CBL                 L399V
#
#                                                 Text  Gene_Share  \
# 0  Cyclin-dependent kinases (CDKs) regulate a var...           1
# 1   Abstract Background  Non-small cell lung canc...           1
# 2   Abstract Background  Non-small cell lung canc...           1
# 3  Recent evidence has demonstrated that acquired...           1
# 4  Oncogenic mutations in the monomeric Casitas B...           1
#
#    Variation_Share
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
#commented for Kaggle Limits
#for i in range(56):
#    df_all['Gene_'+str(i)] = df_all['Gene'].map(lambda x: str(x[i]) if len(x)>i else '')
#    df_all['Variation'+str(i)] = df_all['Variation'].map(lambda x: str(x[i]) if len(x)>i else '')

# %%
gen_var_lst = sorted(list(train.Gene.unique()) + list(train.Variation.unique()))
print(len(gen_var_lst))
gen_var_lst = [x for x in gen_var_lst if len(x.split(' '))==1]
print(len(gen_var_lst))
# Out:
# 3260
# 3091

# %%
gen_var_lst
# Out:
# ['1_2009trunc',
#  '2010_2471trunc',
#  '256_286trunc',
#  '385_418del',
#  '422_605trunc',
#  '533_534del',
#  '534_536del',
#  '550_592del',
#  '560_561insER',
#  '596_619splice',
#  '963_D1010splice',
#  '981_1028splice',
#  'A1020V',
#  'A1022E',
#  'A1065T',
#  'A1066V',
#  'A1099T',
#  'A111P',
#  'A1131T',
#  'A113_splice',
#  'A1170V',
#  'A11_G12insGA',
#  'A1200V',
#  'A120S',
#  'A121E',
#  'A121P',
#  'A121V',
#  'A122*',
#  'A1234T',
#  'A126D',
#  'A126G',
#  'A126S',
#  'A126V',
#  'A134D',
#  'A1374V',
#  'A1459P',
#  'A146T',
#  'A146V',
#  'A148T',
#  'A149P',
#  'A1519T',
#  'A151T',
#  'A159T',
#  'A161S',
#  'A161T',
#  'A1669S',
#  'A1685S',
#  'A1701P',
#  'A1708E',
#  'A1708V',
#  'A171V',
#  'A1752P',
#  'A1752V',
#  'A1789S',
#  'A1789T',
#  'A1823T',
#  'A1830T',
#  'A1843P',
#  'A1843T',
#  'A18D',
#  'A197T',
#  'A19V',
#  'A2034V',
#  'A205T',
#  'A209T',
#  'A211D',
#  'A232V',
#  'A2351G',
#  'A23E',
#  'A2425T',
#  'A246P',
#  'A263V',
#  'A2643G',
#  'A2717S',
#  'A272V',
#  'A2770T',
#  'A290T',
#  'A298T',
#  'A339V',
#  'A347T',
#  'A349P',
#  'A34D',
#  'A36P',
#  'A389T',
#  'A391E',
#  'A39P',
#  'A40E',
#  'A41P',
#  'A41T',
#  'A4419S',
#  'A459V',
#  'A500T',
#  'A502_Y503dup',
#  'A504_Y505ins',
#  'A530T',
#  'A530V',
#  'A532H',
#  'A546D',
#  'A57V',
#  'A598T',
#  'A598V',
#  'A59G',
#  'A59T',
#  'A60V',
#  'A614D',
#  'A617T',
#  'A627T',
#  'A633T',
#  'A633V',
#  'A634D',
#  'A634V',
#  'A636P',
#  'A648T',
#  'A677G',
#  'A707T',
#  'A717G',
#  'A723D',
#  'A727V',
#  'A728V',
#  'A72S',
#  'A72V',
#  'A750P',
#  'A750_E758del',
#  'A750_E758delinsP',
#  'A75P',
#  'A763_Y764insFQEA',
#  'A767_V769del',
#  'A767_V769dup',
#  'A77P',
#  'A77S',
#  'A77T',
#  'A829P',
#  'A859_L883delinsV',
#  'A864T',
#  'A883F',
#  'A883T',
#  'A889P',
#  'A8S',
#  'A919V',
#  'A95D',
#  'ABL1',
#  'ACVR1',
#  'AGO2',
#  'AKT1',
#  'AKT2',
#  'AKT3',
#  'ALK',
#  'APC',
#  'AR',
#  'AR-V7',
#  'ARAF',
#  'ARID1A',
#  'ARID1B',
#  'ARID2',
#  'ARID5B',
#  'ARv567es',
#  'ASXL1',
#  'ASXL2',
#  'ATM',
#  'ATR',
#  'ATRX',
#  'AURKA',
#  'AURKB',
#  'AXIN1',
#  'AXL',
#  'Amplification',
#  'B2M',
#  'BAP1',
#  'BARD1',
#  'BCL10',
#  'BCL2',
#  'BCL2L11',
#  'BCOR',
#  'BRAF',
#  'BRCA1',
#  'BRCA2',
#  'BRD4',
#  'BRIP1',
#  'BTK',
#  'C105F',
#  'C1156F',
#  'C1156Y',
#  'C121S',
#  'C124N',
#  'C124R',
#  'C124S',
#  'C125S',
#  'C1265S',
#  'C134W',
#  'C135R',
#  'C135S',
#  'C135Y',
#  'C1365Y',
#  'C136R',
#  'C136Y',
#  'C1385',
#  'C141Y',
#  'C1483F',
#  'C1483R',
#  'C1483W',
#  'C1483Y',
#  'C157Y',
#  'C1697R',
#  'C1767S',
#  'C176F',
#  'C1787S',
#  'C18Y',
#  'C2060G',
#  'C228T',
#  'C229R',
#  'C238F',
#  'C238S',
#  'C242F',
#  'C242S',
#  'C248T',
#  'C24R',
#  'C24Y',
#  'C250T',
#  'C275S',
#  'C277Q',
#  'C277R',
#  'C277W',
#  'C278F',
#  'C27A',
#  'C311R',
#  'C324Y',
#  'C334S',
#  'C360R',
#  'C378R',
#  'C381A',
#  'C382R',
#  'C384R',
#  'C396R',
#  'C39R',
#  'C39S',
#  'C39Y',
#  'C41Y',
#  'C420R',
#  'C443Y',
#  'C44F',
#  'C44Y',
#  'C450_K451insMIEWMI',
#  'C456_N468del',
#  'C456_R481del',
#  'C47G',
#  'C47S',
#  'C481S',
#  'C482R',
#  'C49Y',
#  'C528S',
#  'C554W',
#  'C569Y',
#  'C582F',
#  'C609Y',
#  'C611Y',
#  'C618R',
#  'C61G',
#  'C620R',
#  'C620Y',
#  'C628Y',
#  'C630R',
#  'C630Y',
#  'C634R',
#  'C634S',
#  'C634W',
#  'C634Y',
#  'C64G',
#  'C696Y',
#  'C706F',
#  'C712R',
#  'C71Y',
#  'C77F',
#  'C809G',
#  'C91A',
#  'C91S',
#  'CARD11',
#  'CARM1',
#  'CASP8',
#  'CASP8L',
#  'CBL',
#  'CCND1',
#  'CCND2',
#  'CCND3',
#  'CCNE1',
#  'CDH1',
#  'CDK12',
#  'CDK4',
#  'CDK6',
#  'CDK8',
#  'CDKN1A',
#  'CDKN1B',
#  'CDKN2A',
#  'CDKN2B',
#  'CDKN2C',
#  'CEBPA',
#  'CHEK2',
#  'CIC',
#  'CREBBP',
#  'CTCF',
#  'CTLA4',
#  'CTNNB1',
#  'D1010H',
#  'D1010N',
#  'D1010Y',
#  'D101Y',
#  'D1029Y',
#  'D1067A',
#  'D1067V',
#  'D1067Y',
#  'D106A',
#  'D1071N',
#  'D107Y',
#  'D108H',
#  'D108N',
#  'D1091N',
#  'D119N',
#  'D1203N',
#  'D121G',
#  'D1270G',
#  'D1280V',
#  'D130A',
#  'D1344H',
#  'D1349H',
#  'D1352Y',
#  'D1384V',
#  'D1399Y',
#  'D140G',
#  'D1420Y',
#  'D153V',
#  'D1546N',
#  'D162G',
#  'D162H',
#  'D1692N',
#  'D1709A',
#  'D1709E',
#  'D171G',
#  'D171N',
#  'D1733G',
#  'D1739E',
#  'D1739G',
#  'D1739V',
#  'D1739Y',
#  'D1778G',
#  'D1778H',
#  'D1778N',
#  'D1778Y',
#  'D1810A',
#  'D1818G',
#  'D1853N',
#  'D186A',
#  'D194Y',
#  'D2033N',
#  'D2312V',
#  'D245V',
#  'D24Y',
#  'D2512G',
#  'D2512Y',
#  'D252G',
#  'D254N',
#  'D257N',
#  'D258N',
#  'D2665G',
#  'D2723G',
#  'D2723H',
#  'D277H',
#  'D2870A',
#  'D287H',
#  'D289_D292del',
#  'D289del',
#  'D29H',
#  'D29Y',
#  'D300H',
#  'D300N',
#  'D3095E',
#  'D3170G',
#  'D323H',
#  'D324N',
#  'D325A',
#  'D326N',
#  'D32A',
#  'D32H',
#  'D32N',
#  'D32Y',
#  'D331G',
#  'D350G',
#  'D351H',
#  'D357Y',
#  'D384N',
#  'D387V',
#  'D390Y',
#  'D399N',
#  'D401N',
#  'D402Y',
#  'D404G',
#  'D408E',
#  'D408H',
#  'D408Y',
#  'D419del',
#  'D422N',
#  'D423N',
#  'D450E',
#  'D450H',
#  'D473G',
#  'D473H',
#  'D493A',
#  'D513Y',
#  'D520N',
#  'D537E',
#  'D537Y',
#  'D544H',
#  'D557H',
#  'D560Y',
#  'D572A',
#  'D579del',
#  'D587H',
#  'D594A',
#  'D594E',
#  'D594G',
#  'D594N',
#  'D594V',
#  'D594Y',
#  'D595V',
#  'D600_L601insFREYEYD',
#  'D603G',
#  'D603N',
#  'D609E',
#  'D60N',
#  'D617G',
#  'D61N',
#  'D61Y',
#  'D631A',
#  'D631G',
#  'D641G',
#  'D641N',
#  'D646Y',
#  'D65N',
#  'D661V',
#  'D661Y',
#  'D67N',
#  'D67Y',
#  'D717V',
#  'D737N',
#  'D74N',
#  'D74Y',
#  'D761Y',
#  'D769A',
#  'D769H',
#  'D769Y',
#  'D770_N771insD',
#  'D770_N771insNPG',
#  'D770_N771insVDSVDNP',
#  'D770_P772dup',
#  'D806H',
#  'D808N',
#  'D814V',
#  'D816A',
#  'D816E',
#  'D816F',
#  'D816G',
#  'D816H',
#  'D816N',
#  'D816V',
#  'D816Y',
#  'D820A',
#  'D820E',
#  'D820G',
#  'D821N',
#  'D835A',
#  'D835E',
#  'D835H',
#  'D835N',
#  'D835Y',
#  'D835del',
#  'D837N',
#  'D839G',
#  'D83V',
#  'D842I',
#  'D842V',
#  'D842Y',
#  'D842_H845del',
#  'D842_M844del',
#  'D845A',
#  'D846Y',
#  'D84G',
#  'D84H',
#  'D84N',
#  'D84V',
#  'D84Y',
#  'D86N',
#  'D887N',
#  'D927G',
#  'D92A',
#  'D92E',
#  'D92G',
#  'D92H',
#  'D92N',
#  'D92V',
#  'D935N',
#  'D96N',
#  'DDR2',
#  'DICER1',
#  'DNMT3A',
#  'DNMT3B',
#  'DNMT3B7',
#  'DUSP4',
#  'Deletion',
#  'E1021K',
#  'E102_I103del',
#  'E1051K',
#  'E1060A',
#  'E106G',
#  'E1071W',
#  'E1099K',
#  'E116K',
#  'E120Q',
#  'E1210K',
#  'E1214K',
#  'E124Q',
#  'E1250K',
#  'E127G',
#  'E1282V',
#  'E1286V',
#  'E1322*',
#  'E1346K',
#  'E1356G',
#  'E135K',
#  'E137K',
#  'E1384K',
#  'E139D',
#  'E14*',
#  'E142D',
#  'E143K',
#  'E144K',
#  'E1552del',
#  'E157G',
#  'E1586G',
#  'E160*',
#  'E161del',
#  'E1644G',
#  'E1660G',
#  'E1682K',
#  'E1682V',
#  'E168D',
#  'E1705A',
#  'E1705K',
#  'E172K',
#  'E1735K',
#  'E1794D',
#  'E1799K',
#  'E17K',
#  'E1836K',
#  'E190K',
#  'E1935G',
#  'E1978*',
#  'E2014K',
#  'E203K',
#  'E207K',
#  'E218*',
#  'E219K',
#  'E221Q',
#  'E239A',
#  'E23fs',
#  'E2419K',
#  'E255K',
#  'E255V',
#  'E258V',
#  'E265K',
#  'E2663V',
#  'E267G',
#  'E275K',
#  'E279K',
#  'E281K',
#  'E2856A',
#  'E285K',
#  'E285V',
#  'E286K',
#  'E29V',
#  'E3002K',
#  'E311_K312del',
#  'E317K',
#  'E31K',
#  'E321G',
#  'E321K',
#  'E322K',
#  'E326L',
#  'E330G',
#  'E330K',
#  'E35*',
#  'E355A',
#  'E362H',
#  'E365K',
#  'E380Q',
#  'E40K',
#  'E40L',
#  'E40N',
#  'E40Q',
#  'E40T',
#  'E40W',
#  'E41A',
#  'E439del',
#  'E452K',
#  'E453A',
#  'E459K',
#  'E462G',
#  'E466K',
#  'E475K',
#  'E483*',
#  'E490K',
#  'E49K',
#  'E501G',
#  'E501K',
#  'E50K',
#  'E518A',
#  'E518K',
#  'E525K',
#  'E541K',
#  'E542G',
#  'E542K',
#  'E542Q',
#  'E542V',
#  'E545A',
#  'E545G',
#  'E545K',
#  'E545Q',
#  'E552K',
#  'E554_I571del',
#  'E554_K558del',
#  'E554_V559del',
#  'E563K',
#  'E565G',
#  'E571K',
#  'E579K',
#  'E580*',
#  'E586K',
#  'E598_Y599insDVDFREYE',
#  'E598_Y599insGLVQVTGSSDNEYFYVDFREYE',
#  'E5K',
#  'E606G',
#  'E60L',
#  'E612_F613insGYVDFREYEYDLKWEFRPRENLEF',
#  'E622D',
#  'E622Q',
#  'E626K',
#  'E627D',
#  'E632_L633del',
#  'E633K',
#  'E636K',
#  'E664K',
#  'E685V',
#  'E69G',
#  'E69K',
#  'E709A',
#  'E709G',
#  'E709K',
#  'E709Q',
#  'E709V',
#  'E709_T710delinsD',
#  'E70K',
#  'E717K',
#  'E719G',
#  'E719K',
#  'E731K',
#  'E734Q',
#  'E746G',
#  'E746Q',
#  'E746V',
#  'E746_A750del',
#  'E746_A750delinsQ',
#  'E746_S752delinsA',
#  'E746_S752delinsI',
#  'E746_T751delinsA',
#  'E746_T751delinsVA',
#  'E746_T751insIP',
#  'E758G',
#  'E75G',
#  'E768D',
#  'E76A',
#  'E76K',
#  'E77K',
#  'E78K',
#  'E79K',
#  'E79Q',
#  'E804G',
#  'E812K',
#  'E81K',
#  'E82D',
#  'E82G',
#  'E82V',
#  'E836K',
#  'E839K',
#  'E846K',
#  'E866K',
#  'E868G',
#  'E872K',
#  'E875G',
#  'E884K',
#  'E88K',
#  'E921K',
#  'E946*',
#  'E996K',
#  'EGFR',
#  'EGFR-KDD',
#  'EGFRvII',
#  'EGFRvIII',
#  'EGFRvIV',
#  'EGFRvV',
#  'EIF1AX',
#  'ELF3',
#  'EP300',
#  'EPAS1',
#  'EPCAM',
#  'ERBB2',
#  'ERBB3',
#  'ERBB4',
#  'ERCC2',
#  'ERCC3',
#  'ERCC4',
#  'ERG',
#  'ERRFI1',
#  'ESR1',
#  'ETV1',
#  'ETV6',
#  'EWSR1',
#  'EZH2',
#  'F102C',
#  'F1061W',
#  'F1088Lfs*5',
#  'F1088Sfs*2',
#  'F1174I',
#  'F1174L',
#  'F119S',
#  'F1200I',
#  'F123I',
#  'F1245C',
#  'F1245V',
#  'F129L',
#  'F12L',
#  'F133L',
#  'F133V',
#  'F134Y',
#  'F1524V',
#  'F154L',
#  'F156L',
#  'F158C',
#  'F1592S',
#  'F161L',
#  'F1662S',
#  'F1695L',
#  'F1704S',
#  'F170I',
#  'F1734S',
#  'F1761I',
#  'F1761S',
#  'F1888I',
#  'F1888L',
#  'F1888V',
#  'F2108L',
#  'F212Y',
#  'F21A',
#  'F241S',
#  'F248S',
#  'F28L',
#  'F311L',
#  'F317L',
#  'F31I',
#  'F328V',
#  'F341C',
#  'F341V',
#  'F346V',
#  'F347L',
#  'F351L',
#  'F354L',
#  'F359C',
#  'F367S',
#  'F384L',
#  'F384V',
#  'F384Y',
#  'F400I',
#  'F460L',
#  'F468C',
#  'F522C',
#  'F537_K539delinsL',
#  'F53C',
#  'F53L',
#  'F53S',
#  'F568fs',
#  'F57C',
#  'F57L',
#  'F57V',
#  'F590G',
#  'F594L',
#  'F594_R595insSDNEYFYVDF',
#  'F615S',
#  'F691L',
#  'F71I',
#  'F74S',
#  'F79S',
#  'F808L',
#  'F81V',
#  'F876L',
#  'F877L',
#  'F893L',
#  'F958S',
#  'F958V',
#  'FAM58A',
#  'FANCA',
#  'FANCC',
#  'FAT1',
#  'FBXW7',
#  'FGF19',
#  'FGF3',
#  'FGF4',
#  'FGFR1',
#  'FGFR2',
#  'FGFR3',
#  'FGFR4',
#  'FLT1',
#  'FLT3',
#  'FOXA1',
#  'FOXL2',
#  'FOXO1',
#  'FOXP1',
#  'FUBP1',
#  'Fusions',
#  'G101S',
#  'G101W',
#  'G1035S',
#  'G106D',
#  'G106V',
#  'G106_R108del',
#  'G1079D',
#  'G1123D',
#  'G1123S',
#  'G1125A',
#  'G1128A',
#  'G1128S',
#  'G114R',
#  'G116S',
#  'G118D',
#  'G1194D',
#  'G1201E',
#  'G1202R',
#  'G1232D',
#  'G123R',
#  'G123S',
#  'G1269A',
#  'G1269S',
#  'G127E',
#  'G127N',
#  'G1286R',
#  'G128V',
#  'G129A',
#  'G129E',
#  'G129R',
#  'G12A',
#  'G12C',
#  'G12D',
#  'G12F',
#  'G12R',
#  'G12S',
#  'G12V',
#  'G13C',
#  'G13D',
#  'G13E',
#  'G13R',
#  'G13V',
#  'G14V',
#  'G1529R',
#  'G1567D',
#  'G1596V',
#  'G161V',
#  'G163D',
#  'G1656D',
#  'G165E',
#  'G165R',
#  'G165V',
#  'G1706A',
#  'G1706E',
#  'G1738E',
#  'G1738R',
#  'G1743R',
#  'G1763V',
#  'G1770V',
#  'G1788D',
#  'G1788V',
#  'G17A',
#  'G17E',
#  'G17V',
#  'G1803A',
#  'G1809K',
#  'G1809R',
#  'G186R',
#  'G1971E',
#  'G199R',
#  'G2032R',
#  'G207E',
#  'G20E',
#  'G2101A',
#  'G216R',
#  'G2274V',
#  'G23D',
#  'G2430A',
#  'G244D',
#  'G244R',
#  'G244S',
#  'G245A',
#  'G245D',
#  'G245S',
#  'G248V',
#  'G250E',
#  'G251C',
#  'G253C',
#  'G264S',
#  'G266E',
#  'G266R',
#  'G271E',
#  'G2748D',
#  'G284R',
#  'G305R',
#  'G305W',
#  'G309A',
#  'G309E',
#  'G311D',
#  'G31A',
#  'G31R',
#  'G31V',
#  'G322S',
#  'G325A',
#  'G325R',
#  'G328E',
#  'G328V',
#  'G333S',
#  'G334R',
#  'G34E',
#  'G34V',
#  'G356A',
#  'G35A',
#  'G35R',
#  'G35V',
#  'G370C',
#  'G373R',
#  'G375C',
#  'G375P',
#  'G376R',
#  'G380R',
#  'G382D',
#  'G39E',
#  'G419V',
#  'G423R',
#  'G423V',
#  'G42R',
#  'G430C',
#  'G434R',
#  'G44S',
#  'G464A',
#  'G464E',
#  'G464R',
#  'G464V',
#  'G465E',
#  'G466A',
#  'G466E',
#  'G466R',
#  'G466V',
#  'G469A',
#  'G469E',
#  'G469V',
#  'G469del',
#  'G478C',
#  'G480W',
#  'G503V',
#  'G505S',
#  'G508S',
#  'G52R',
#  'G591V',
#  'G596C',
#  'G596R',
#  'G596V',
#  'G602R',
#  'G60D',
#  'G60E',
#  'G60R',
#  'G623R',
#  'G637W',
#  'G660D',
#  'G665A',
#  'G67R',
#  'G67S',
#  'G67W',
#  'G697C',
#  'G701S',
#  'G70D',
#  'G719A',
#  'G719C',
#  'G719D',
#  'G719S',
#  'G724S',
#  'G735S',
#  'G751R',
#  'G75R',
#  'G774V',
#  ...]

# %%
#***RYO: This part was commented out for Kaggle Limits in the public kernel
#***RYO: %100 was replaced with %300
#i_ = 0
#for gen_var_lst_itm in gen_var_lst:
#    if i_ % 300 == 0: print(i_)
#    df_all['GV_'+str(gen_var_lst_itm)] = df_all['Text'].map(lambda x: str(x).count(str(gen_var_lst_itm)))
#    i_ += 1

# %%
#***RYO's comment
# Create new sets of columns for Gene and Variation columns
# One holds numerical label, one holds length of the gene name, 
# and another holds how many words the gene name has.
# For the text, count the number of characters and number of words.***
for c in df_all.columns:
    if df_all[c].dtype == 'object':
        if c in ['Gene','Variation']:
            lbl = LabelEncoder()
            df_all[c+'_lbl_enc'] = lbl.fit_transform(df_all[c].values)  
            df_all[c+'_len'] = df_all[c].map(lambda x: len(str(x)))
            df_all[c+'_words'] = df_all[c].map(lambda x: len(str(x).split(' ')))
        elif c != 'Text':
            lbl = LabelEncoder()
            df_all[c] = lbl.fit_transform(df_all[c].values)
        if c=='Text': 
            df_all[c+'_len'] = df_all[c].map(lambda x: len(str(x)))
            df_all[c+'_words'] = df_all[c].map(lambda x: len(str(x).split(' ')))

# %%
df_all.head(50)
# Out:
#     ID    Gene                  Variation  \
# 0    0  FAM58A       Truncating Mutations
# 1    1     CBL                      W802*
# 2    2     CBL                      Q249E
# 3    3     CBL                      N454D
# 4    4     CBL                      L399V
# 5    5     CBL                      V391I
# 6    6     CBL                      V430M
# 7    7     CBL                   Deletion
# 8    8     CBL                      Y371H
# 9    9     CBL                      C384R
# 10  10     CBL                      P395A
# 11  11     CBL                      K382E
# 12  12     CBL                      R420Q
# 13  13     CBL                      C381A
# 14  14     CBL                      P428L
# 15  15     CBL                      D390Y
# 16  16     CBL       Truncating Mutations
# 17  17     CBL                      Q367P
# 18  18     CBL                      M374V
# 19  19     CBL                      Y371S
# 20  20     CBL                       H94Y
# 21  21     CBL                      C396R
# 22  22     CBL                      G375P
# 23  23     CBL                      S376F
# 24  24     CBL                      P417A
# 25  25     CBL                      H398Y
# 26  26   SHOC2                        S2G
# 27  27    TERT                      Y846C
# 28  28    TERT                      C228T
# 29  29    TERT                      H412Y
# 30  30    TERT                      H876Q
# 31  31    TERT         Promoter Mutations
# 32  32    TERT                      P704S
# 33  33    TERT              Amplification
# 34  34    TERT                      C250T
# 35  35  DICER1                     G1809R
# 36  36  DICER1                     G1809K
# 37  37  DICER1                     D1709E
# 38  38  DICER1                     D1709A
# 39  39  DICER1                     E1705A
# 40  40  DICER1                     D1810A
# 41  41  DICER1       Truncating Mutations
# 42  42  DICER1                     E1705K
# 43  43  DICER1                   Deletion
# 44  44   PTPRT                     T1365M
# 45  45   PTPRT                      V648G
# 46  46   PTPRT                      T844M
# 47  47   PTPRT                      A707T
# 48  48   PTPRT  Promoter Hypermethylation
# 49  49   PTPRT                     R1343L
#
#                                                  Text  Gene_Share  \
# 0   Cyclin-dependent kinases (CDKs) regulate a var...           1
# 1    Abstract Background  Non-small cell lung canc...           1
# 2    Abstract Background  Non-small cell lung canc...           1
# 3   Recent evidence has demonstrated that acquired...           1
# 4   Oncogenic mutations in the monomeric Casitas B...           1
# 5   Oncogenic mutations in the monomeric Casitas B...           1
# 6   Oncogenic mutations in the monomeric Casitas B...           1
# 7   CBL is a negative regulator of activated recep...           1
# 8    Abstract Juvenile myelomonocytic leukemia (JM...           1
# 9    Abstract Juvenile myelomonocytic leukemia (JM...           1
# 10  Oncogenic mutations in the monomeric Casitas B...           1
# 11  Noonan syndrome is an autosomal dominant conge...           1
# 12  Noonan syndrome is an autosomal dominant conge...           1
# 13  Noonan syndrome is an autosomal dominant conge...           1
# 14  Oncogenic mutations in the monomeric Casitas B...           1
# 15  Noonan syndrome is an autosomal dominant conge...           1
# 16  To determine if residual cylindrical refractiv...           1
# 17  Acquired uniparental disomy (aUPD) is a common...           1
# 18  Oncogenic mutations in the monomeric Casitas B...           1
# 19  Acquired uniparental disomy (aUPD) is a common...           1
# 20   Abstract Background  Non-small cell lung canc...           1
# 21  Oncogenic mutations in the monomeric Casitas B...           1
# 22  Oncogenic mutations in the monomeric Casitas B...           1
# 23  Recent evidence has demonstrated that acquired...           1
# 24  Recent evidence has demonstrated that acquired...           1
# 25  Recent evidence has demonstrated that acquired...           1
# 26   Abstract N-myristoylation is a common form of...           1
# 27  Heterozygous mutations in the telomerase compo...           1
# 28  Sequencing studies have identified many recurr...           1
# 29  Heterozygous mutations in the telomerase compo...           1
# 30  Heterozygous mutations in the telomerase compo...           1
# 31  Sequencing studies have identified many recurr...           1
# 32  Heterozygous mutations in the telomerase compo...           1
# 33  The current World Health Organization classifi...           1
# 34  Sequencing studies have identified many recurr...           1
# 35   Abstract  DICER1 plays a critical role in mic...           1
# 36   Abstract  DICER1 plays a critical role in mic...           1
# 37  Sex cord–stromal tumors and germ-cell tumors a...           1
# 38  Sex cord–stromal tumors and germ-cell tumors a...           1
# 39  Human Dicer contains two RNase III domains (RN...           0
# 40  Human Dicer contains two RNase III domains (RN...           0
# 41  Mesenchymal cell populations contribute to mic...           1
# 42  Sex cord–stromal tumors and germ-cell tumors a...           1
# 43  Mesenchymal cell populations contribute to mic...           1
# 44  Tyrosine phosphorylation, regulated by protein...           1
# 45  The receptor protein tyrosine phosphatase T (P...           1
# 46  Introduction  Preceding hematologic disorders ...           0
# 47  The receptor protein tyrosine phosphatase T (P...           1
# 48  Metastasis is the leading cause of death for g...           1
# 49  Tyrosine phosphorylation, regulated by protein...           1
#
#     Variation_Share  Gene_lbl_enc  Gene_len  Gene_words  Variation_lbl_enc  \
# 0                 1           447         6           1               7654
# 1                 1           216         3           1               8255
# 2                 1           216         3           1               5191
# 3                 1           216         3           1               4572
# 4                 1           216         3           1               3958
# 5                 1           216         3           1               7898
# 6                 1           216         3           1               7913
# 7                 0           216         3           1               1350
# 8                 1           216         3           1               8435
# 9                 1           216         3           1                716
# 10                1           216         3           1               4939
# 11                1           216         3           1               3483
# 12                1           216         3           1               6206
# 13                1           216         3           1                713
# 14                0           216         3           1               4961
# 15                0           216         3           1               1128
# 16                1           216         3           1               7654
# 17                0           216         3           1               5236
# 18                1           216         3           1               4319
# 19                0           216         3           1               8436
# 20                0           216         3           1               3081
# 21                0           216         3           1                721
# 22                1           216         3           1               2518
# 23                0           216         3           1               7042
# 24                1           216         3           1               4953
# 25                0           216         3           1               3005
# 26                1          1211         5           1               6993
# 27                1          1353         4           1               8566
# 28                1          1353         4           1                625
# 29                1          1353         4           1               3008
# 30                1          1353         4           1               3072
# 31                2          1353         4           1               5113
# 32                1          1353         4           1               5062
# 33                0          1353         4           1                493
# 34                1          1353         4           1                647
# 35                1           349         6           1               2257
# 36                1           349         6           1               2256
# 37                0           349         6           1                955
# 38                1           349         6           1                954
# 39                0           349         6           1               1428
# 40                0           349         6           1                976
# 41                1           349         6           1               7654
# 42                1           349         6           1               1429
# 43                1           349         6           1               1350
# 44                0          1082         5           1               7292
# 45                1          1082         5           1               8010
# 46                0          1082         5           1               7622
# 47                1          1082         5           1                421
# 48                0          1082         5           1               5112
# 49                0          1082         5           1               5461
#
#     Variation_len  Variation_words  Text_len  Text_words
# 0              20                2     39672        6105
# 1               5                1     36691        5783
# 2               5                1     36691        5783
# 3               5                1     36238        5625
# 4               5                1     41308        6248
# 5               5                1     41308        6248
# 6               5                1     41308        6248
# 7               8                1     98867       14709
# 8               5                1     79774       12009
# 9               5                1     38465        5761
# 10              5                1     41308        6248
# 11              5                1     83371       12251
# 12              5                1    173604       25745
# 13              5                1     83371       12251
# 14              5                1     41308        6248
# 15              5                1     42062        6003
# 16             20                2     54507        8206
# 17              5                1     20698        3013
# 18              5                1     41308        6248
# 19              5                1     20698        3013
# 20              4                1     78000       12031
# 21              5                1     41308        6248
# 22              5                1     41308        6248
# 23              5                1     36238        5625
# 24              5                1     36238        5625
# 25              5                1     36238        5625
# 26              3                1     45168        6693
# 27              5                1      9290        1422
# 28              5                1     90766       13862
# 29              5                1      9290        1422
# 30              5                1      9290        1422
# 31             18                2    138955       21096
# 32              5                1      9290        1422
# 33             13                1     64031        9632
# 34              5                1    119255       18124
# 35              6                1     36336        5311
# 36              6                1     36336        5311
# 37              6                1     18555        2710
# 38              6                1     18555        2710
# 39              6                1     38941        6280
# 40              6                1     38941        6280
# 41             20                2    123192       18101
# 42              6                1     18555        2710
# 43              8                1    127485       18620
# 44              6                1     13014        1958
# 45              5                1     25462        3746
# 46              5                1      9081        1330
# 47              5                1     25462        3746
# 48             25                2     58716        8565
# 49              6                1     13014        1958

# %%
train = df_all.iloc[:len(train)]
test = df_all.iloc[len(train):]

# %%
class cust_regression_vals(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin):
    def fit(self, x, y=None):
        return self
    def transform(self, x):
        x = x.drop(['Gene', 'Variation','ID','Text'],axis=1).values
        return x

class cust_txt_col(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin):
    def __init__(self, key):
        self.key = key
    def fit(self, x, y=None):
        return self
    def transform(self, x):
        return x[self.key].apply(str)

# %%
print('Pipeline...')
fp = pipeline.Pipeline([
    ('union', pipeline.FeatureUnion(
        n_jobs = -1,
        transformer_list = [
            ('standard', cust_regression_vals()),
            ('pi1', pipeline.Pipeline([('Gene', cust_txt_col('Gene')), ('count_Gene', feature_extraction.text.CountVectorizer(analyzer=u'char', ngram_range=(1, 8))), ('tsvd1', decomposition.TruncatedSVD(n_components=20, n_iter=25, random_state=12))])),
            ('pi2', pipeline.Pipeline([('Variation', cust_txt_col('Variation')), ('count_Variation', feature_extraction.text.CountVectorizer(analyzer=u'char', ngram_range=(1, 8))), ('tsvd2', decomposition.TruncatedSVD(n_components=20, n_iter=25, random_state=12))])),
            #commented for Kaggle Limits
            #('pi3', pipeline.Pipeline([('Text', cust_txt_col('Text')), ('tfidf_Text', feature_extraction.text.TfidfVectorizer(ngram_range=(1, 2))), ('tsvd3', decomposition.TruncatedSVD(n_components=50, n_iter=25, random_state=12))]))
        ])
    )])

train = fp.fit_transform(train); print(train.shape)
test = fp.transform(test); print(test.shape)
# Out:
# Pipeline...
# (3321, 50)
# (5668, 50)

# %%
y = y - 1 #fix for zero bound array

denom = 0
fold = 1 #Change to 5, 1 for Kaggle Limits
for i in range(fold):
    params = {
        'eta': 0.03333,
        'max_depth': 4,
        'objective': 'multi:softprob',
        'eval_metric': 'mlogloss',
        'num_class': 9,
        'seed': i,
        'silent': True
    }
    x1, x2, y1, y2 = model_selection.train_test_split(train, y, test_size=0.18, random_state=i)
    watchlist = [(xgb.DMatrix(x1, y1), 'train'), (xgb.DMatrix(x2, y2), 'valid')]
    model = xgb.train(params, xgb.DMatrix(x1, y1), 1000,  watchlist, verbose_eval=50, early_stopping_rounds=100)
    score1 = metrics.log_loss(y2, model.predict(xgb.DMatrix(x2), ntree_limit=model.best_ntree_limit), labels = list(range(9)))
    print(score1)
    #if score < 0.9:
    if denom != 0:
        pred = model.predict(xgb.DMatrix(test), ntree_limit=model.best_ntree_limit+80)
        preds += pred
    else:
        pred = model.predict(xgb.DMatrix(test), ntree_limit=model.best_ntree_limit+80)
        preds = pred.copy()
    denom += 1
    submission = pd.DataFrame(pred, columns=['class'+str(c+1) for c in range(9)])
    submission['ID'] = pid
    #submission.to_csv('submission_xgb_fold_'  + str(i) + '.csv', index=False)
preds /= denom
#submission = pd.DataFrame(preds, columns=['class'+str(c+1) for c in range(9)])
submission['ID'] = pid
#submission.to_csv('submission_xgb.csv', index=False)
# Out:
# [0]	train-mlogloss:2.14625	valid-mlogloss:2.1518
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:1.22697	valid-mlogloss:1.37848
# [100]	train-mlogloss:0.962159	valid-mlogloss:1.20367
# [150]	train-mlogloss:0.811314	valid-mlogloss:1.13104
# [200]	train-mlogloss:0.707752	valid-mlogloss:1.0993
# [250]	train-mlogloss:0.628141	valid-mlogloss:1.07859
# [300]	train-mlogloss:0.564709	valid-mlogloss:1.06977
# [350]	train-mlogloss:0.511379	valid-mlogloss:1.06579
# [400]	train-mlogloss:0.466618	valid-mlogloss:1.06384
# [450]	train-mlogloss:0.42542	valid-mlogloss:1.06362
# [500]	train-mlogloss:0.385764	valid-mlogloss:1.06294
# Stopping. Best iteration:
# [425]	train-mlogloss:0.446482	valid-mlogloss:1.06274
#
# 1.06274188304

# %%
print(submission.shape)
submission.head()
# Out:
# (5668, 10)
#      class1    class2    class3    class4    class5    class6    class7  \
# 0  0.253041  0.054113  0.361450  0.065566  0.066544  0.009476  0.175423
# 1  0.203772  0.088146  0.009943  0.311965  0.031091  0.017503  0.331196
# 2  0.228855  0.280346  0.003842  0.243845  0.064525  0.010433  0.166777
# 3  0.229815  0.068399  0.010867  0.289495  0.071386  0.026421  0.287756
# 4  0.265078  0.175754  0.006064  0.237577  0.098730  0.188054  0.024646
#
#      class8    class9  ID
# 0  0.005165  0.009222   0
# 1  0.000707  0.005678   1
# 2  0.000984  0.000393   2
# 3  0.000638  0.015222   3
# 4  0.003120  0.000976   4
