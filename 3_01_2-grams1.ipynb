# %% [markdown]
# <a id='sec0'></a>

# %% [markdown]
# # Extracting 2-gram features

# %% [markdown]
# The extracted words here will be combined with others extracted in different ways
#
# <a href='#sec1'><b>1. Import and pre-process data</b></a>
#
# <a href='#sec2'><b>2. Create features based on frequency paramerization</b></a>
#
# <a href='#sec3'><b>3. PCA & LDA</b></a>

# %%
import csv
import json
import random
import re
import numpy as np
import pandas as pd
import scipy.stats as scs
import matplotlib.pyplot as plt
import importlib as imp
import feature_engineering.frequency_selection as fefs
import feature_engineering.text_processing as fetp
import myplot.decomposition as mpd

from nltk import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# Slow version of gensim.models.doc2vec is being used

# %% [markdown]
# <a id='sec1'></a>
# # 1. Import and pre-process data
# (<a href='#sec0'>Back to top</a>)

# %%
class_train = pd.read_csv('./data/training_variants')
text_train = pd.read_csv("./data/training_text", sep=r"\|\|", engine='python',
                         header=None, skiprows=1, names=["ID","Text"])
train = class_train.merge(text_train, on='ID')

# create class label container
class_labels = []
for i in range(9):
    class_labels.append('class' + str(i+1))

# %%
doc1 = train.iloc[0]['Text']

# %%
tokenized_doc = word_tokenize(fetp.replace_with_whitespace(doc1, hyphens='on'))

stemmer = PorterStemmer()
tokenized_doc = [stemmer.stem(word) for word in tokenized_doc]
processed_doc = [' '.join(tokenized_doc)]

stop_words = set(stopwords.words('english'))
stemmed_stop_words = [stemmer.stem(word) for word in stop_words]

remove_words = ['also', 'anoth', 'case', 'fig', 'gave', 'illustr', 'result', 'show', 'suggest', 'supplementari', 'tabl', 'play', 
                'use', 'pictur', 'could', 'woukd', 'might', 'demonstr', 'whether', 'almost', 'elut', 'find', 'give', 'henc',
                'known', 'ml', 'name', 'ncbi', 'onlin', 'previous', 'purifi', 'method', 'must', 'seem', 'whose', 'when', 'where',
                'this', 'thus', 'town', 'wa', 'wash', 'download', 'yet']

# %%
ngram_vectorizer = CountVectorizer(analyzer='word', ngram_range=(2, 2))
counts = ngram_vectorizer.fit_transform(processed_doc)

# %%
ngrams_unfiltered = ngram_vectorizer.get_feature_names()

# %%
# %%time
ngrams_filtered = []
ngrams_filtered_indices = []
for i, term in enumerate(ngrams_unfiltered):
    word1, word2 = term.split(' ')
    if not (re.search(r'^[A-Za-z]', word1) and re.search(r'^[A-Za-z]', word2)):
        continue
    if not (re.search(r'[A-Za-z0-9]$', word1) and re.search(r'[A-Za-z0-9]$', word2)):
        continue
    if (re.search(r'[@#%&*()+=]', word1) or re.search(r'[@#%&*()+=]', word2)):
        contiue
    if not (len(word1) > 1 or len(word2) > 1):
        continue
    if ((word1.lower() in stemmed_stop_words) or (word2.lower() in stemmed_stop_words)):
        continue
    if ((word1.lower() in remove_words) or (word2.lower() in remove_words)):
        continue
        
    ngrams_filtered.append(term)
    ngrams_filtered_indices.append(i)
# Out:
# CPU times: user 27.6 ms, sys: 972 µs, total: 28.6 ms
# Wall time: 28.1 ms

# %%
len(ngrams_filtered)
# Out:
# 1307

# %%
ngram_vectorizer2 = CountVectorizer(analyzer='word', ngram_range=(2, 2), vocabulary=ngrams_filtered)
ngram_vectorizer2.fit_transform(processed_doc)
# Out:
# <1x1307 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1307 stored elements in Compressed Sparse Row format>

# %%
ngram_vectorizer2.get_feature_names()
# Out:
# ['abcam ab9106',
#  'aberr splice',
#  'abnorm three',
#  'abolish atp',
#  'acceptor site',
#  'acid genbank',
#  'acid mop',
#  'acid number',
#  'acid sequenc',
#  'acid substitut',
#  'actin sigma',
#  'activ chromosom',
#  'activ cyclin',
#  'activ peg202',
#  'activ posit',
#  'activ protein',
#  'activ reveal',
#  'activ treatment',
#  'ad amount',
#  'ad kinas',
#  'ad laemli',
#  'ad sampl',
#  'addit anomali',
#  'addit evid',
#  'addit regulatori',
#  'adult tissu',
#  'affect individu',
#  'affin interact',
#  'agaros bead',
#  'ago cdk10',
#  'alanin substitut',
#  'albeit notabl',
#  'allow dock',
#  'alreadi report',
#  'altern exon',
#  'altern gene',
#  'altern splice',
#  'although discov',
#  'amino acid',
#  'amino termin',
#  'anal atresia',
#  'analysi quantit',
#  'analyz chromosom',
#  'analyz sall1',
#  'anti actin',
#  'anti cdk10',
#  'anti cycm',
#  'anti ets2',
#  'anti flag',
#  'anti goat',
#  'anti mous',
#  'anti myc',
#  'anti rabbit',
#  'anti raf1',
#  'anti tubulin',
#  'anti v5',
#  'antibodi anti',
#  'antibodi detect',
#  'antibodi input',
#  'antibodi product',
#  'apc cdh1',
#  'appar telecanthu',
#  'array cgh',
#  'array compar',
#  'array enrich',
#  'arrow indic',
#  'ascertain bia',
#  'assay amino',
#  'assay reveal',
#  'assay transfect',
#  'assay western',
#  'associ cyclin',
#  'associ fam58a',
#  'atp bind',
#  'atyp site',
#  'author note',
#  'autonom function',
#  'autosom domin',
#  'avail copi',
#  'b42 respect',
#  'b42 transcript',
#  'bac system',
#  'bait protein',
#  'bead buffer',
#  'bead harbor',
#  'bead incub',
#  'bead thermo',
#  'bear alanin',
#  'bear d181a',
#  'bear delet',
#  'bear fam58a',
#  'bi tri',
#  'bind domain',
#  'bind partner',
#  'bind stabil',
#  'bio rad',
#  'biolog function',
#  'biotechnolog sc',
#  'black box',
#  'blot accord',
#  'blot analysi',
#  'blot experi',
#  'blot reveal',
#  'blot top',
#  'blue yeast',
#  'bodi size',
#  'bona fide',
#  'box fold',
#  'box indic',
#  'bp code',
#  'bradford assay',
#  'brain develop',
#  'breakpoint clone',
#  'breast cancer',
#  'bring evid',
#  'broad tripartit',
#  'broader spectrum',
#  'brock okihiro',
#  'brock syndrom',
#  'buffer contain',
#  'buffer heat',
#  'buffer one',
#  'buffer pb',
#  'buffer see',
#  'call transcript',
#  'cancer cdk10',
#  'cancer cell',
#  'cancer deriv',
#  'cancer mcf7',
#  'cancer patient',
#  'captur gst',
#  'cardin featur',
#  'caus decreas',
#  'caus mark',
#  'caus star',
#  'caus tamoxifen',
#  'ccnd1 encod',
#  'cdh1 mediat',
#  'cdi1 kap',
#  'cdk cdk7',
#  'cdk discov',
#  'cdk famili',
#  'cdk interact',
#  'cdk phosphoryl',
#  'cdk protein',
#  'cdk regul',
#  'cdk without',
#  'cdk10 alon',
#  'cdk10 antibodi',
#  'cdk10 coexpress',
#  'cdk10 covalab',
#  'cdk10 cyclin',
#  'cdk10 cycm',
#  'cdk10 express',
#  'cdk10 function',
#  'cdk10 gene',
#  'cdk10 independ',
#  'cdk10 interact',
#  'cdk10 isoform',
#  'cdk10 kd',
#  'cdk10 kinas',
#  'cdk10 knockdown',
#  'cdk10 may',
#  'cdk10 modul',
#  'cdk10 p1',
#  'cdk10 p2',
#  'cdk10 protein',
#  'cdk10 remain',
#  'cdk10 silenc',
#  'cdk10 stand',
#  'cdk10 strepii',
#  'cdk10 upper',
#  'cdk10 within',
#  'cdk10 wt',
#  'cdk10kd produc',
#  'cdk11 protein',
#  'cdna plasmid',
#  'cell carri',
#  'cell cdk10',
#  'cell coexpress',
#  'cell cotransfect',
#  'cell cultur',
#  'cell cycl',
#  'cell deriv',
#  'cell disruptor',
#  'cell divis',
#  'cell either',
#  'cell express',
#  'cell input',
#  'cell line',
#  'cell lysat',
#  'cell previou',
#  'cell prolifer',
#  'cell respect',
#  'cell shown',
#  'cell western',
#  'cellular model',
#  'cellular process',
#  'certain type',
#  'cgh analysi',
#  'cgh data',
#  'cgh investig',
#  'characterist facial',
#  'chemiluminesc supersign',
#  'chromosom inactiv',
#  'clinic featur',
#  'clinic marker',
#  'clinic overlap',
#  'clinic phenotyp',
#  'clinic unaffect',
#  'closest paralog',
#  'cnv databas',
#  'co immunoprecipit',
#  'cobalt bead',
#  'code exon',
#  'code region',
#  'codon n68xfsx1',
#  'coexpress flag',
#  'coexpress gst',
#  'coexpress involv',
#  'coexpress myc',
#  'coexpress pair',
#  'cognat endogen',
#  'cognat target',
#  'coktail roch',
#  'collect cell',
#  'coloboma epilepsi',
#  'colon cervix',
#  'combin accord',
#  'combin silenc',
#  'compar genom',
#  'complet skew',
#  'complex schemat',
#  'compromis cdk10',
#  'concert action',
#  'confer tamoxifen',
#  'confirm patern',
#  'conserv splice',
#  'construct tamoxifen',
#  'contain cyclin',
#  'contain proteas',
#  'control antibodi',
#  'control cell',
#  'control ets2',
#  'control goat',
#  'control lymphoblastoid',
#  'coomassi stain',
#  'cooper mediat',
#  'copi number',
#  'copurifi thu',
#  'correspond gene',
#  'coupl anti',
#  'covalab pab0847p',
#  'covalab pab0882',
#  'cranial abnorm',
#  'cruz biotechnolog',
#  'cullin ring',
#  'custom oligonucleotid',
#  'cut gel',
#  'cycl control',
#  'cycl regul',
#  'cyclin albeit',
#  'cyclin although',
#  'cyclin antibodi',
#  'cyclin associ',
#  'cyclin bind',
#  'cyclin box',
#  'cyclin caus',
#  'cyclin cdna',
#  'cyclin coexpress',
#  'cyclin control',
#  'cyclin copurifi',
#  'cyclin cyclin',
#  'cyclin d1',
#  'cyclin d2',
#  'cyclin depend',
#  'cyclin directli',
#  'cyclin domain',
#  'cyclin express',
#  'cyclin famili',
#  'cyclin form',
#  'cyclin fusion',
#  'cyclin gene',
#  'cyclin heterodim',
#  'cyclin isoform',
#  'cyclin kinas',
#  'cyclin level',
#  'cyclin lower',
#  'cyclin mrna',
#  'cyclin mutant',
#  'cyclin origin',
#  'cyclin partner',
#  'cyclin pathway',
#  'cyclin phosphoryl',
#  'cyclin posit',
#  'cyclin protect',
#  'cyclin protein',
#  'cyclin silenc',
#  'cyclin sirna',
#  'cyclin stabil',
#  'cyclin tag',
#  'cyclin v5',
#  'cyclin within',
#  'cycm fusion',
#  'cycm home',
#  'cycm produc',
#  'cycm v5',
#  'd1 coloc',
#  'd1 knockout',
#  'd1 p21',
#  'd181a amino',
#  'd2 ref',
#  'data log2',
#  'databas subsequ',
#  'date13 although',
#  'daught pair1',
#  'daughter pair',
#  'de novo',
#  'de3 novagen',
#  'dead kd',
#  'decreas cdk10',
#  'decreas cell',
#  'decreas cyclin',
#  'decreas express',
#  'decreas risk',
#  'degrad involv',
#  'delet extend',
#  'delet found',
#  'delet involv',
#  'delet overlap',
#  'delet remov',
#  'delet size',
#  'delta shape',
#  'deorphan cdk10',
#  'depend cdk10',
#  'depend kinas',
#  'depend protein',
#  'derepress ets2',
#  'deriv cell',
#  'deriv lymphoblastoid',
#  'destruct box',
#  'detect cyclin',
#  'detect de',
#  'detect decreas',
#  'detect fam58a',
#  'detect gst',
#  'detect phenotyp',
#  'detect small',
#  'detect strong',
#  'develop certain',
#  'develop fam58a',
#  'development anomali',
#  'development pathway',
#  'development stage',
#  'dh10bac escherichia',
#  'differ amino',
#  'differ cdk10',
#  'differ fam58a',
#  'differ isoform',
#  'differ observ',
#  'differ protein',
#  'differ significantli',
#  'differ sirna',
#  'direct fashion',
#  'direct link',
#  'direct regul',
#  'directli ad',
#  'directli control',
#  'divis previou',
#  'dmem supplement',
#  'dna bind',
#  'dock mediat',
#  'domain found',
#  'domain green',
#  'domain protein',
#  'domin entiti',
#  'domin phenotyp',
#  'donor site',
#  'doublet correspond',
#  'doublet observ',
#  'dramat decreas',
#  'driven activ',
#  'driven raf',
#  'driven transcript',
#  'duplic overlap',
#  'dusp9 howev',
#  'dysmorph facial',
#  'dysplast ear',
#  'dystroph chang',
#  'e26 oncogen',
#  'edta mm',
#  'edta roch',
#  'effect cdk10',
#  'egta mm',
#  'egta nonidet',
#  'either individu',
#  'either monomer',
#  'either overexpress',
#  'either posit',
#  'electropor neon',
#  'embryogenesis7 cyclin',
#  'embryon kidney',
#  'empti bait',
#  'empti vector',
#  'encod cyclin',
#  'encod protein',
#  'endogen cdk10',
#  'endogen cyclin',
#  'endogen ets2',
#  'endogen protein',
#  'endogen raf',
#  'enhanc chemiluminesc',
#  'enhanc ets2',
#  'enhanc upon',
#  'entir krt18p48',
#  'entiti mim601446',
#  'er breast',
#  'er mcf7',
#  'erk express',
#  'erk2 protein',
#  'erythroblastosi viru',
#  'escherichia coli',
#  'est data',
#  'establish direct',
#  'estrogen receptor',
#  'et erythroblastosi',
#  'ets2 activ',
#  'ets2 cdk10',
#  'ets2 degrad',
#  'ets2 dosag',
#  'ets2 driven',
#  'ets2 et',
#  'ets2 ets2',
#  'ets2 exert',
#  'ets2 exist',
#  'ets2 express',
#  'ets2 level',
#  'ets2 mrna',
#  'ets2 phosphoryl',
#  'ets2 present',
#  'ets2 protein',
#  'ets2 santa',
#  'ets2 stabil',
#  'ets2 transgen',
#  'ets2 wild',
#  'ets2dbm bear',
#  'ets2sasa compar',
#  'ets2sasa protein',
#  'ets2sasa remain',
#  'exact delet',
#  'excess compar',
#  'exert noncel',
#  'exhibit compromis',
#  'exogen coexpress',
#  'exogen express',
#  'exon amplicon',
#  'exon box',
#  'exon includ',
#  'exon indic',
#  'expect consequ',
#  'experi confirm',
#  'express alon',
#  'express caus',
#  'express cyclin',
#  'express differ',
#  'express flag',
#  'express level',
#  'express lexa',
#  'express observ',
#  'express quantif',
#  'express untag',
#  'express vector',
#  'express viewer',
#  'express western',
#  'facial appear',
#  'facial featur',
#  'fam58a contain',
#  'fam58a gene',
#  'fam58a interact',
#  'fam58a mrna',
#  'fam58a mutat',
#  'fam58a point',
#  'fam58a sequenc',
#  'fam58a specif',
#  'famili owe',
#  'fashion especi',
#  'fb invitrogen',
#  'featur includ',
#  'featur normal',
#  'feingold syndrom',
#  'femal affect',
#  'femal control',
#  'femto thermo',
#  'fetal develop',
#  'fetal loss',
#  'fetu gene',
#  'fide cdk',
#  'figur clinic',
#  'final concentr',
#  'final resuspend',
#  'fine mechan',
#  'fisher scientif',
#  'five code',
#  'flag ets2',
#  'flag ets2dbm',
#  'flag ets2sasa',
#  'flag sigma',
#  'flag tag',
#  'flank gene',
#  'fold domain',
#  'follow primari',
#  'form noncanon',
#  'form phosphodegron',
#  'formal identif',
#  'found complet',
#  'found heterozyg',
#  'four differ',
#  'four ray',
#  'four time',
#  'four unrel',
#  'frameshift mutat',
#  'frequent deregul',
#  'full length',
#  'full size',
#  'function cdk10',
#  'function gene',
#  'function interact',
#  'function mutat',
#  'function relev',
#  'function remain',
#  'fundament cellular',
#  'furthermor fam58a',
#  'fusion protein',
#  'gel migrat',
#  'gel slice',
#  'genbank list',
#  'gene atp2b3',
#  'gene caus',
#  'gene consist',
#  'gene encod',
#  'gene found',
#  'gene homolog',
#  'gene id',
#  'gene mutat',
#  'gene possibl',
#  'gene product',
#  'gene schemat',
#  'gene silenc',
#  'gene splice',
#  'gener explor',
#  'gener recombin',
#  'gener substrat',
#  'genet diseas',
#  'genom contain',
#  'genom dna',
#  'genom hybrid',
#  'genom wide',
#  'genuin cyclin',
#  'glutamax supplement',
#  'glutathion sepharos',
#  'goat antibodi',
#  'goat santa',
#  'grew human',
#  'grew lymphoblastoid',
#  'growth disadvantag',
#  'growth retard',
#  'gst cdk10',
#  'gst cdk10kd',
#  'gst fusion',
#  'h1 lysat',
#  'h1 phosphoryl',
#  'half present',
#  'harbor gst',
#  'healthi individu',
#  'heat denatur',
#  'hek293 cell',
#  'heparin ph',
#  'heterodim wherea',
#  'heterozyg delet',
#  'heterozyg fam58a',
#  'heterozyg femal',
#  'high affin',
#  'high resolut',
#  'higher resist',
#  'highli specif',
#  'histon h1',
#  'home made',
#  'homogen clinic',
#  'homogen phenotyp',
#  'homolog driven',
#  'homolog transcript',
#  'homozyg knockout',
#  'horizont arrow',
#  'horizont bar',
#  'horizont line',
#  'hormon therapi',
#  'howev contrari',
#  'howev multipl',
#  'hrp coupl',
#  'human breast',
#  'human cancer',
#  'human cdk10',
#  'human cell',
#  'human cyclin',
#  'human development',
#  'human embryon',
#  'human fam58a',
#  'human genet',
#  'human genom',
#  'human hek293',
#  'human phenotyp',
#  'hybond nitrocellulos',
#  'hybrid cgh',
#  'hybrid interact',
#  'hybrid y2h',
#  'hypoplast labia',
#  'hypothes cdk10',
#  'hypothet product',
#  'identifi cyclin',
#  'identifi delet',
#  'identifi four',
#  'identifi heterozyg',
#  'imidazol mm',
#  'imidazol ph',
#  'immedi stop',
#  'immunoprecipit experi',
#  'immunoprecipit myc',
#  'immunoprecipit obtain',
#  'implic first',
#  'import role',
#  'inactiv furthermor',
#  'includ apc',
#  'includ exon',
#  'includ kidney',
#  'includ missens',
#  'includ model',
#  'includ toe',
#  'incomplet skew',
#  'incorpor radioact',
#  'increas ets2',
#  'increas express',
#  'increas raf',
#  'increas risk',
#  'increas upon',
#  'incub bead',
#  'inde genuin',
#  'independ round',
#  'indic black',
#  'indic differ',
#  'indic intern',
#  'individu quantif',
#  'induc express',
#  'induc resist',
#  'induc tamoxifen',
#  'infect sf9',
#  'inform snp',
#  'inhibitor coktail',
#  'inhibitor mg132',
#  'inhibitor mixtur',
#  'inhibitor proper',
#  'input correspond',
#  'insect cell',
#  'insert event',
#  'interact assay',
#  'interact complex',
#  'interact mate',
#  'interact phenotyp',
#  'interact protein',
#  'interact robustli',
#  'interact signal',
#  'interest hypothesi',
#  'intern delet',
#  'intringuingli one',
#  'intron respect',
#  'intronless gene',
#  'invitrogen r960',
#  'involv cdk10',
#  'involv fam58a',
#  'involv number',
#  'isoform analyz',
#  'isoform interact',
#  'isoform p1',
#  'isoform produc',
#  'isopropyl thiogalactopyranosid',
#  'jetprim polyplu',
#  'kb delet',
#  'kb overlap',
#  'kd either',
#  'kd fusion',
#  'kd howev',
#  'kd immunoprecipit',
#  'kd mutant',
#  'kd strepii',
#  'key role',
#  'kidney cell',
#  'kidney colon',
#  'kinas activ',
#  'kinas assay',
#  'kinas buffer',
#  'kinas cdk',
#  'kinas dead',
#  'knockdown derepress',
#  'knockout mice',
#  'knockout mice7',
#  'knowledg gap',
#  'krt18p48 pseudogen',
#  'labia anal',
#  'laemli sampl',
#  'larg imped',
#  'larg rescu',
#  'larger delet',
#  'last orphan',
#  'latter cell',
#  'left lane',
#  'length cyclin',
#  'lesser extent',
#  'level achiev',
#  'level altogeth',
#  'level observ',
#  'level western',
#  'level would',
#  'lexa dna',
#  'lid coloboma',
#  'ligas crl4',
#  'ligas involv',
#  'like aris',
#  'like cdk10',
#  'line compar',
#  'line deriv',
#  'line hek293',
#  'line transfect',
#  'link domin',
#  'lipofectamin rnaimax',
#  'list mrna',
#  'list tumor',
#  'live protein',
#  'locat approxim',
#  'log2 ratio',
#  'longer gel',
#  'longest cdk10',
#  'low final',
#  'lower band',
#  'lower lid',
#  'lower middl',
#  'lower silenc',
#  'lymphoblastoid cell',
#  'lysat obtain',
#  'lysi buffer',
#  'made dilut',
#  'major decreas',
#  'malform dysmorph',
#  'mammalian cell',
#  'mani cancer',
#  'manner similar',
#  'manufactur instruct',
#  'mapk pathway',
#  'margin fluctuat',
#  'mark decreas',
#  'mass spectrometri',
#  'mate assay',
#  'may belong',
#  'may form',
#  'mb centromer',
#  'mcf7 cell',
#  'mcf7 total',
#  'mechan caus',
#  'mechan cdk10',
#  'mechan underli',
#  'mediat cdk10',
#  'mediat decay',
#  'mediat degrad',
#  'mediat gene',
#  'mediat phosphoryl',
#  'mediat transcript',
#  'medic implic',
#  'mg132 fisher',
#  'mg132 larg',
#  'mg132 proteasom',
#  'mgcl2 mm',
#  'mice7 therefor',
#  'missens chang',
#  'mix glutathion',
#  'mixtur roch',
#  'mixtur spun',
#  'mixtur without',
#  'mm dtt',
#  'mm edta',
#  'mm egta',
#  'mm glycerophosph',
#  'mm imidazol',
#  'mm isopropyl',
#  'mm mgcl2',
#  'mm morpholino',
#  'mm na',
#  'mm nacl',
#  'mm naf',
#  'mm nitrophenylphosph',
#  'mm tri',
#  'mm tris',
#  'model includ',
#  'modul ets2',
#  'molecular character',
#  'molecular dock',
#  'molecular mechan',
#  'mop ph',
#  'morpholino propanesulfon',
#  'mother daught',
#  'mother daughter',
#  'mous bio',
#  'mous model',
#  'mous protein',
#  'mrna express',
#  'mrna follow',
#  'mrna length',
#  'mrna level',
#  'mrna similar',
#  'mrna undergo',
#  'much reduc',
#  'multipl phosphoryl',
#  'murin chromosom',
#  'mutant bear',
#  'mutant protein',
#  'mutat allel',
#  'mutat caus',
#  'mutat fam58a',
#  'mutat includ',
#  'mutat lead',
#  'mutat mrna',
#  'myc abcam',
#  'myc antibodi',
#  'myc cdk10',
#  'mycn fam58a',
#  'mycn gene',
#  'na vanad',
#  'nacl mm',
#  'nacl nonidet',
#  'nasal tip',
#  'neg control',
#  'neighbor gene',
#  'neighbor phospho',
#  'neighbor serin',
#  'neon invitrogen',
#  'new window',
#  'nitrocellulos membran',
#  'non prolin',
#  'noncanon trcp',
#  'noncel autonom',
#  'nonsens mediat',
#  'nonspecif signal',
#  'nontransfect mcf7',
#  'normal intellect',
#  'notabl weaker',
#  'note clinic',
#  'note mycn',
#  'novo heterozyg',
#  'novo statu',
#  'number loss',
#  'number variat',
#  'observ upon',
#  'observ varieti',
#  'offer straightforward',
#  'oligonucleotid array',
#  'oncogen homolog',
#  'one altern',
#  'one probe',
#  'one time',
#  'onto hybond',
#  'origami2 de3',
#  'orphan cdk',
#  'orphan cyclin',
#  'overlap consider',
#  'overlap exon',
#  'overlap fam58a',
#  'overlap phenotyp',
#  'p1 express',
#  'p1 y2h',
#  'p2 isoform',
#  'p21 cip1',
#  'pab0882 dilut',
#  'pair wise',
#  'panel comigr',
#  'parent consent',
#  'parent origin',
#  'partial decreas',
#  'partli respons',
#  'partner mutat',
#  'patient deriv',
#  'patient identifi',
#  'patient strongli',
#  'patient third',
#  'pcr analysi',
#  'pcr mass',
#  'pellet heat',
#  'perform immunoprecipit',
#  'perform y2h',
#  'perform yeast',
#  'ph contain',
#  'ph mm',
#  'phenocopi cdk10',
#  'phenotyp overlap',
#  'phenotyp repres',
#  'phenotyp similar',
#  'phenotyp thu',
#  'phenotyp y2h',
#  'phenylphosph nonidet',
#  'phospho erk',
#  'phospho serin',
#  'phosphodegron dsmcpa',
#  'phosphoryl erk1',
#  'phosphoryl ets2',
#  'phosphoryl level',
#  'phosphoryl residu',
#  'phosphoryl site',
#  'phosphoryl substrat',
#  'phosphoryl varieti',
#  'photograph anal',
#  'photoreceptor cell',
#  'physic interact',
#  'pink horizont',
#  'pivot role',
#  'plasmid construct',
#  'plasmid express',
#  'plasmid lipofectamin',
#  'plasmid sirna',
#  'player includ',
#  'point domain',
#  'point mutat',
#  'pool mix',
#  'pool silenc',
#  'posit breast',
#  'posit cell',
#  'posit control',
#  'posit role',
#  'posit within',
#  'possibl atp2b3',
#  'pptfig cdk10',
#  'pptfig cyclin',
#  'pptfig decreas',
#  'preced observ',
#  'preced prolin',
#  'precis mechan',
#  'predict absenc',
#  'predict clinic',
#  'pregenom era',
#  'prematur stop',
#  'present number',
#  'present sever',
#  'present strong',
#  'previou sectionnext',
#  'previou studi',
#  'previou work',
#  'prey plasmid',
#  'prey protein',
#  'prey respect',
#  'primari antibodi',
#  'probe posit',
#  'probe span',
#  'process cdk10',
#  'produc gst',
#  'produc interact',
#  'produc strong',
#  'produc virus',
#  'produc y2h',
#  'prolifer assay',
#  'prolifer defect',
#  'prolifer previou',
#  'prolin direct',
#  'promot tumor',
#  'propanesulfon acid',
#  'proper express',
#  'proteas inhibitor',
#  'proteasom ets2',
#  'proteasom inhibitor',
#  'protect cdk10',
#  'protein alon',
#  'protein bind',
#  'protein content',
#  'protein cooper',
#  'protein correspond',
#  'protein degrad',
#  'protein express',
#  'protein femal',
#  'protein gst',
#  'protein isoform',
#  'protein kinas',
#  'protein level',
#  'protein mutant',
#  'protein onto',
#  'protein produc',
#  'protein protein',
#  'provid invitrogen',
#  'qpcr analysi',
#  'quantit rt',
#  'rabbit bio',
#  'rad dri',
#  'raf express',
#  'raf mrna',
#  'raf protein',
#  'raf transcript',
#  'raf1 santa',
#  ...]
